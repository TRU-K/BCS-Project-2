# %%
# !pip install plotly
# Out:
# Collecting plotly
#   Downloading plotly-5.9.0-py2.py3-none-any.whl (15.2 MB)
#      ---------------------------------------- 15.2/15.2 MB 4.4 MB/s eta 0:00:00
# Collecting tenacity>=6.2.0
#   Downloading tenacity-8.0.1-py3-none-any.whl (24 kB)
# Installing collected packages: tenacity, plotly
# Successfully installed plotly-5.9.0 tenacity-8.0.1

# %%
# Library imports
import panel as pn
pn.extension('plotly')
from panel.interact import interact
import plotly.tools
import pandas as pd
import hvplot.pandas
# Out:
# <style>.bk-root, .bk-root .bk:before, .bk-root .bk:after {
#   font-family: var(--jp-ui-font-size1);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--jp-ui-font-color1);
# }
# </style>

# %%
df = pd.read_csv('../Data/EFT_optimised_signals.csv', header=[0, 1], parse_dates=True, index_col=[0])
bb_signals_df = pd.read_csv('../Data/BB_optimiser_record.csv', header=[0], index_col=[0])
df = df.sort_index(axis=1)

# %%
ticker_list = list(dict.fromkeys((df.droplevel(axis=1, level=[-1]))))

# %%
df['GDXJ']
# Out:
#                 Close  Dividends   EMA_long  EMA_short       High        Low  \
# Date
# 2017-07-10  30.682661        0.0  30.682661  30.682661  30.720940  29.639487
# 2017-07-11  30.797503        0.0  30.688263  30.720942  30.854926  30.089294
# 2017-07-12  30.912348        0.0  30.699194  30.784744  31.352585  30.864497
# 2017-07-13  30.519962        0.0  30.690451  30.696483  31.046333  30.414689
# 2017-07-14  31.008057        0.0  30.705944  30.800341  31.247316  30.893209
# ...               ...        ...        ...        ...        ...        ...
# 2022-07-01  33.049999        0.0  38.079203  33.438485  33.270000  31.230000
# 2022-07-05  31.070000        0.0  37.737291  32.648990  32.560001  30.490000
# 2022-07-06  30.670000        0.0  37.392545  31.989326  31.290001  29.820000
# 2022-07-07  31.370001        0.0  37.098762  31.782885  31.889999  30.840000
# 2022-07-08  31.209999        0.0  36.811505  31.591923  31.809999  30.730000
#
#                  Open  Stock Splits    Volume signal
# Date
# 2017-07-10  29.639487             0  14885900    buy
# 2017-07-11  30.634804             0   8459900    buy
# 2017-07-12  31.132466             0   9287200    buy
# 2017-07-13  30.912348             0   8345500    buy
# 2017-07-14  31.046335             0  12389200    buy
# ...               ...           ...       ...    ...
# 2022-07-01  31.440001             0   9314200    NaN
# 2022-07-05  32.459999             0  11897900    NaN
# 2022-07-06  31.000000             0   8244700    NaN
# 2022-07-07  30.980000             0   6398300    NaN
# 2022-07-08  31.379999             0   5845600    NaN
#
# [1259 rows x 10 columns]

# %%
# Create a Title for the Dashboard
dashboard_title = '# Machine Learning Project'

# Define a welcome text
welcome_message =  '''
    ### Welcome to Kurt, Matt and Anita's Dashboard
    '''

welcome_message_2 = '''
    In this Dasboard you will find analysis, comparing our two Machine Learning Models [Model name 1] and
    [Model name 2]. You will also see what our feature and target data sets consists of.
    '''

welcome_pane = pn.Column(
    dashboard_title,
    welcome_message,
)

# Create panels to structure the layout of the dashboard
tab_1 = pn.Column()

tab_2 = pn.Column()

tab_3 = pn.Column()

tab_4 = pn.Column()

tab_5 = pn.Column()

dashboard = pn.Tabs(
    ('Welcome', welcome_pane),
    ('Welcome 2', welcome_pane_2),
    ('Tab 1', tab_1),
    ('Tab 2', tab_2),
    ('Tab 3', tab_3),
    ('Tab 4', tab_4),
    ('Tab 5', tab_5)
)

# %%
dashboard.servable()
# Out:
# Tabs
#     [0] Column
#         [0] Markdown(str)
#         [1] Markdown(str)
#     [1] Column
#         [0] Markdown(str)
#         [1] Markdown(str)
#     [2] Column()
#     [3] Column()
#     [4] Column()
#     [5] Column()
#     [6] Column()
