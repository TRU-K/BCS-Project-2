# %%
# Import libraries and dependencies
import talib as ta
from talib import abstract
from talib import MA_Type
import pandas as pd
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_680/3231331351.py in <module>
#       1 # Import libraries and dependencies
# ----> 2 import talib as ta
#       3 from talib import abstract
#       4 from talib import MA_Type
#       5 import pandas as pd
#
# ModuleNotFoundError: No module named 'talib'

# %%
# Read in data
df = pd.read_csv('../Data/ETF_data_including_signal_data.csv', header=[0, 1], parse_dates=True, index_col=[0])

# %%
# Create a list of the tickers for later use
ticker_list = list(dict.fromkeys((df.droplevel(axis=1, level=[-1]))))

# %%
# Initialize multi level dataframe
indicator_metrics_df = pd.DataFrame(columns=[[], []])

# %%
# A for loop that will iterate through all tickers and add indicator metrics to the above dataframe
for x in ticker_list:
    
    # ATR indicator
    ATR = ta.ATR(df[x]['high'], df[x]['low'], df[x]['close'], timeperiod=14)
    indicator_metrics_df[x, 'ATR'] = ATR
    
    # CCI indicator
    CCI = ta.CCI(df[x]['high'], df[x]['low'], df[x]['close'], timeperiod=14)
    indicator_metrics_df[x, 'CCI'] = CCI
    
    # MACD indicator
    # Because this indicator creates a tuple of arrays, unlike the above indicators which create only a single
    # array. We first create a new dataframe containing the data, iterate through it appending each column
    # to the 'indicator_metrics_df' dataframe
    MACD = ta.MACD(df[x]['close'], fastperiod=12, slowperiod=26, signalperiod=9)
    MACD_df = pd.DataFrame(MACD).transpose()
    MACD_df.rename(columns={0:'MACD_FAST_PERIOD', 1:'MACD_SLOW_PERIOD', 2:'MACD_SIGNAL_PERIOD'}, inplace=True)
    for line in MACD_df:
        indicator_metrics_df[x, line] = MACD_df[line]  
    
    # RSI indicator
    RSI = ta.RSI(df[x]['close'], timeperiod=14)
    indicator_metrics_df[x, 'RSI'] = RSI

# Sort the columns labels
indicator_metrics_df = indicator_metrics_df.sort_index(axis=1)

# %%
# Write to CSV file
indicator_metrics_df.to_csv('../Data/engineered_features.csv')

# %%
# Indicator metrics only dataframe sample
indicator_metrics_df.sample(5).sort_index(axis=0)
# Out:
#                  GDX                                                  \
#                  ATR         CCI MACD_FAST_PERIOD MACD_SIGNAL_PERIOD
# Date
# 2017-10-18  0.370838  -24.854785        -0.042124          -0.000086
# 2018-01-30  0.462263  -74.195062         0.278737          -0.060569
# 2020-01-09  0.607141  -48.088916         0.447811          -0.040367
# 2020-04-14  2.158681  207.307047         0.838754           0.888431
# 2020-05-26  1.477057  -55.692572         1.330318          -0.269686
#
#                                             GDXJ                               \
#            MACD_SLOW_PERIOD        RSI       ATR         CCI MACD_FAST_PERIOD
# Date
# 2017-10-18        -0.042039  45.997019  0.660252  -89.620297        -0.141229
# 2018-01-30         0.339306  48.980072  0.794507 -154.529569         0.257061
# 2020-01-09         0.488179  48.923253  1.029972  -37.199922         0.855709
# 2020-04-14        -0.049676  64.118194  3.387523  195.531556         0.392889
# 2020-05-26         1.600004  51.789088  2.144602   26.363739         2.203671
#
#                                ...              XLU                     \
#            MACD_SIGNAL_PERIOD  ... MACD_FAST_PERIOD MACD_SIGNAL_PERIOD
# Date                           ...
# 2017-10-18          -0.056499  ...         0.088944           0.088264
# 2018-01-30          -0.212030  ...        -0.600457           0.130663
# 2020-01-09          -0.071313  ...         0.287407          -0.045540
# 2020-04-14           1.354173  ...        -0.261499           1.216572
# 2020-05-26          -0.023860  ...        -0.263767           0.131755
#
#                                              XLV                               \
#            MACD_SLOW_PERIOD        RSI       ATR         CCI MACD_FAST_PERIOD
# Date
# 2017-10-18         0.000680  55.677602  0.562298  171.220948         0.410647
# 2018-01-30        -0.731120  39.037895  0.824385   59.985968         1.658805
# 2020-01-09         0.332947  58.854372  0.835936  145.421055         1.129802
# 2020-04-14        -1.478071  55.289053  3.722538  136.669540         0.833541
# 2020-05-26        -0.395522  51.120496  1.942813   14.160592         0.997324
#
#
#            MACD_SIGNAL_PERIOD MACD_SLOW_PERIOD        RSI
# Date
# 2017-10-18          -0.007465         0.418112  64.089953
# 2018-01-30           0.200312         1.458493  64.574921
# 2020-01-09          -0.159839         1.289641  69.773013
# 2020-04-14           1.709343        -0.875802  59.744235
# 2020-05-26          -0.321283         1.318607  53.140034
#
# [5 rows x 48 columns]

# %%
# A for loop that will iterate through all tickers and add indicator metrics to the above dataframe
for x in ticker_list:
    
    # ATR indicator
    ATR = ta.ATR(df[x]['high'], df[x]['low'], df[x]['close'], timeperiod=14)
    df[x, 'ATR'] = ATR
    
    # CCI indicator
    CCI = ta.CCI(df[x]['high'], df[x]['low'], df[x]['close'], timeperiod=14)
    df[x, 'CCI'] = CCI
    
    # MACD indicator
    # Because this indicator creates a tuple of arrays, unlike the above indicators which create only a single
    # array. We first create a new dataframe containing the data, iterate through it appending each column
    # to the 'indicator_metrics_df' dataframe
    MACD = ta.MACD(df[x]['close'], fastperiod=12, slowperiod=26, signalperiod=9)
    MACD_df = pd.DataFrame(MACD).transpose()
    MACD_df.rename(columns={0:'MACD_FAST_PERIOD', 1:'MACD_SLOW_PERIOD', 2:'MACD_SIGNAL_PERIOD'}, inplace=True)
    for line in MACD_df:
        df[x, line] = MACD_df[line]  
    
    # RSI indicator
    RSI = ta.RSI(df[x]['close'], timeperiod=14)
    df[x, 'RSI'] = RSI

# Sort the columns labels
df = df.sort_index(axis=1)

# %%
# Write to CSV file
df.to_csv('../Data/ETF_data_including_engineered_features_and_signals.csv')

# %%
# Whole dataframe sample
df.sample(5).sort_index(axis=0)
# Out:
#                  GDX                                               \
#                  ATR   BB_LOWER  BB_MIDDLE   BB_UPPER         CCI
# Date
# 2017-11-20  0.320066  21.394286  21.703197  22.012109  -60.195962
# 2018-03-08  0.497255  20.290831  21.156914  22.022997  -55.980532
# 2018-08-31  0.422194  17.018632  18.707374  20.396116  -70.693400
# 2020-10-09  1.283816  35.885495  39.020863  42.156232  179.153635
# 2022-03-02  1.115141  29.477375  33.030500  36.583625  102.011849
#
#                                                                             \
#            MACD_FAST_PERIOD MACD_SIGNAL_PERIOD MACD_SLOW_PERIOD        RSI
# Date
# 2017-11-20        -0.154074           0.026456        -0.180530  43.088744
# 2018-03-08        -0.326745           0.018388        -0.345134  43.104578
# 2018-08-31        -0.622778           0.033826        -0.656605  34.262002
# 2020-10-09        -0.478736           0.076184        -0.554920  54.104423
# 2022-03-02         1.107348           0.252201         0.855147  67.125824
#
#                    ...              XLV                                \
#            SIGNAL  ... MACD_SLOW_PERIOD        RSI SIGNAL       close
# Date               ...
# 2017-11-20    0.0  ...        -0.226333  41.774219    0.0   74.564758
# 2018-03-08    0.0  ...        -0.326427  52.256463    0.0   78.915977
# 2018-08-31    0.0  ...         1.107481  81.036041    0.0   86.477119
# 2020-10-09    0.0  ...        -0.050416  61.614611   -1.0  105.562645
# 2022-03-02    0.0  ...        -1.084612  52.125312    0.0  130.232254
#
#                                                                        \
#            dividends        high         low        open stock splits
# Date
# 2017-11-20       0.0   74.933436   74.444934   74.868918            0
# 2018-03-08       0.0   78.980753   78.471801   78.601353            0
# 2018-08-31       0.0   86.551686   86.122937   86.290709            0
# 2020-10-09       0.0  105.874384  104.929423  105.202194            0
# 2022-03-02       0.0  130.937062  128.693567  128.862324            0
#
#
#               volume
# Date
# 2017-11-20   4898500
# 2018-03-08   6403000
# 2018-08-31   5808100
# 2020-10-09   5636300
# 2022-03-02  12395600
#
# [5 rows x 136 columns]
